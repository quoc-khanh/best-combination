# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset/FinalDatasetHomeCreditDefaultRisk.csv
# /kaggle/input/dataset/cleaned_hmeq.csv
# /kaggle/input/dataset/UCI_Credit_Card.csv
# /kaggle/input/dataset/german.csv

# %% [markdown]
# We choose these models:\
# RandomForestClassifier \
# XGBoost\
# CatBoost\
# LightGBM\
# StackingClassifier\
#
# SMOTE (oversampling)\
# ClusterCentroid (undersampling)\
# SMOTEENN (hybrid: OS and US)\
# cWGAN (NN)\
#
# Balanced Random Forest (ensemble)\
# Class Weights \ass Weights

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.combine import SMOTEENN, SMOTETomek
from imblearn.pipeline import make_pipeline

# SMOTE for oversampling
smote_pipeline = make_pipeline(
    SMOTE()  # Apply SMOTE to oversample the minority class
)

# ClusterCentroids for undersampling
cluster_centroid_pipeline = make_pipeline(
    ClusterCentroids()  # Apply ClusterCentroids to undersample the majority class
)

# SMOTEENN for hybrid oversampling and undersampling
smoteenn_pipeline = make_pipeline(
    SMOTEENN()  # Apply SMOTEENN to balance the dataset
)

# SMOTETomek for hybrid oversampling and undersampling
smotetomek_pipeline = make_pipeline(
    SMOTETomek()  # Apply SMOTETomek to balance the dataset
)

# %%
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    make_scorer
)
from sklearn.model_selection import cross_validate, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns


class ModelEvaluatorWithLibrary:
    def __init__(self, models, threshold=0.5, cv_splits=5):
        self.models = models
        self.threshold = threshold
        self.cv_splits = cv_splits

    def evaluate_model_with_cv(self, X, y, model, scoring_metrics):
        """
        Perform cross-validation using the provided metrics.
        """
        cv = StratifiedKFold(n_splits=self.cv_splits, shuffle=True, random_state=42)
        cv_results = cross_validate(
            model, X, y, cv=cv, scoring=scoring_metrics, return_train_score=False
        )
        
        # Mean scores for each metric
        model_scores = {metric: cv_results[f'test_{metric}'].mean() for metric in scoring_metrics}
        return model_scores

    def evaluate_model_on_test(self, X_train, y_train, X_test, y_test, model):
        """
        Train the model and evaluate it on the test set.
        """
        model.fit(X_train, y_train)
        y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, 'predict_proba') else model.predict(X_test)
        y_pred = (y_prob >= self.threshold).astype(int)

        scores = {
            'accuracy': accuracy_score(y_test, y_pred),
            'f1': f1_score(y_test, y_pred, zero_division=0),
            'auc_roc': roc_auc_score(y_test, y_prob),
        }

        return scores, y_pred

    def score_models(self, X_train, y_train, X_test, y_test):
        """
        Evaluate all models on cross-validation and the test set.
        """
        scoring_metrics = {
            'f1': 'f1',
            'accuracy': 'accuracy',
            'auc_roc': 'roc_auc'
        }

        scores = {}
        
        for name, model in self.models.items():
            print(f"Evaluating model: {name}")
            
            # Cross-validation scores
            cv_scores = self.evaluate_model_with_cv(X_train, y_train, model, scoring_metrics)
            
            # Test set evaluation
            test_scores, y_pred = self.evaluate_model_on_test(X_train, y_train, X_test, y_test, model)
            
            # Store both cross-validation and test set results
            scores[name] = {
                #'cross_val': cv_scores,
                'test': test_scores
            }
            
            # Plot confusion matrix for the current model
            #print(f"Confusion Matrix for {name}:")
            #self.plot_confusion_matrix(y_test, y_pred, labels=[0, 1])

        return scores

    def plot_confusion_matrix(self, y_test, y_pred, labels):
        """
        Plot the confusion matrix.
        """
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(10, 7))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title('Confusion Matrix')
        plt.show()

# %%
RANDOM_STATE = 42
threshold = 0.5

# %%
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

models = {
    'RandomForestClassifier': RandomForestClassifier(random_state=RANDOM_STATE),
    'XGBClassifier': XGBClassifier(random_state=RANDOM_STATE),
    'CatBoostClassifier': CatBoostClassifier(verbose=False, random_state=RANDOM_STATE),
    'LightGBMClassifier': LGBMClassifier(
        random_state=RANDOM_STATE,
        verbose=-1
    ),
    'StackingClassifier': StackingClassifier(
        estimators=[
            ('rf', RandomForestClassifier(random_state=RANDOM_STATE)),
            ('xgb', XGBClassifier(random_state=RANDOM_STATE)),
            ('catboost', CatBoostClassifier(verbose=False, random_state=RANDOM_STATE)),
            ('lgbm', LGBMClassifier(
                random_state=RANDOM_STATE,
                verbose=-1
            ))
        ],
        final_estimator=LogisticRegression(),
        cv=5
    )
}

# Initialize evaluator
evaluator = ModelEvaluatorWithLibrary(models=models)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
import numpy as np

paths = ['/kaggle/input/dataset/german.csv', '/kaggle/input/dataset/cleaned_hmeq.csv', '/kaggle/input/dataset/UCI_Credit_Card.csv', '/kaggle/input/dataset/FinalDatasetHomeCreditDefaultRisk.csv']
balmethods = ['smote', 'cc', 'smoteenn', 'smotetomek']
for path in paths:
    for balmethod in balmethods:
        print('-'*100)
        print('-'*100)
        print(f'DATASET: {path}')
        print(f'BALANCING METHOD: {balmethod}')
        print('')
        df = pd.read_csv(path)
    
        df = df.replace([np.inf, -np.inf], 0)
        
        if path == '/kaggle/input/dataset/german.csv':
            target_col = 'Status_loan'
            #df = df.drop('')
        elif path == '/kaggle/input/dataset/cleaned_hmeq.csv':
            target_col = 'BAD'
            #df = df.drop('')
        elif path == '/kaggle/input/dataset/UCI_Credit_Card.csv':
            target_col = 'default.payment.next.month'
            df = df.drop('ID', axis=1)
        elif path == '/kaggle/input/dataset/FinalDatasetHomeCreditDefaultRisk.csv':
            target_col = 'TARGET'
            df = df.drop('SK_ID_CURR', axis=1)
        
        # Define columns dynamically based on data types
        cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
        num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
        
        # Remove target column from cat_cols or num_cols if present
        if target_col in cat_cols:
            cat_cols.remove(target_col)
        elif target_col in num_cols:
            num_cols.remove(target_col)
        for col in cat_cols:
            df[col] = df[col].astype(str)
        
        X = df.loc[:, num_cols + cat_cols]
        y = df[target_col]
        
        print(target_col)
        print(y[y==0].count())
        print(y[y==1].count())
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2024, stratify=y)
        # Define numerical and categorical column transformers
        num_prep = make_pipeline(SimpleImputer(strategy='mean'),
                                 MinMaxScaler())
        
        # Using OrdinalEncoder for numerical-like encoding of categorical columns
        cat_prep = make_pipeline(SimpleImputer(strategy='most_frequent'),
                                 OneHotEncoder())
        
        # Combine both transformers into a ColumnTransformer
        prep = ColumnTransformer([
            ('num', num_prep, num_cols),
            ('cat', cat_prep, cat_cols)
            ],
            remainder='drop')
        
        # Apply transformations to training and test sets
        X_train_trans = prep.fit_transform(X_train)
        X_test_trans = prep.transform(X_test)
        if balmethod == 'smote':
            X_train_trans, y_train = smote_pipeline.fit_resample(X_train_trans, y_train)
        elif balmethod == 'cc':
            X_train_trans, y_train = cluster_centroid_pipeline.fit_resample(X_train_trans, y_train)
        elif balmethod == 'smoteenn':
            X_train_trans, y_train = smoteenn_pipeline.fit_resample(X_train_trans, y_train)
        elif balmethod == 'smotetomek':
            X_train_trans, y_train = smotetomek_pipeline.fit_resample(X_train_trans, y_train)
        else: print('X'*1000)
    
        # Output the shapes of the balanced datasets
        print(f"Balanced X_train shape: {X_train_trans.shape}")
        print(f"Balanced y_train shape: {y_train.shape}")
    
        X_train = X_train_trans
        X_test = X_test_trans
        X = X_train
        y = y_train
        
        scores = evaluator.score_models(X_train, y_train, X_test, y_test)
        print(scores)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/german.csv
# BALANCING METHOD: smote
#
# Status_loan
# 700
# 300
# Balanced X_train shape: (1120, 61)
# Balanced y_train shape: (1120,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.755, 'f1': 0.5663716814159292, 'auc_roc': 0.7787500000000002}}, 'XGBClassifier': {'test': {'accuracy': 0.735, 'f1': 0.5546218487394957, 'auc_roc': 0.7741666666666666}}, 'CatBoostClassifier': {'test': {'accuracy': 0.775, 'f1': 0.6153846153846154, 'auc_roc': 0.8153571428571429}}, 'LightGBMClassifier': {'test': {'accuracy': 0.735, 'f1': 0.5470085470085471, 'auc_roc': 0.7748809523809524}}, 'StackingClassifier': {'test': {'accuracy': 0.775, 'f1': 0.6017699115044247, 'auc_roc': 0.7935714285714285}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/german.csv
# BALANCING METHOD: cc
#
# Status_loan
# 700
# 300
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Balanced X_train shape: (480, 61)
# Balanced y_train shape: (480,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.59, 'f1': 0.5494505494505496, 'auc_roc': 0.7567857142857143}}, 'XGBClassifier': {'test': {'accuracy': 0.56, 'f1': 0.5217391304347827, 'auc_roc': 0.6966666666666667}}, 'CatBoostClassifier': {'test': {'accuracy': 0.59, 'f1': 0.5494505494505496, 'auc_roc': 0.7413095238095238}}, 'LightGBMClassifier': {'test': {'accuracy': 0.57, 'f1': 0.5376344086021505, 'auc_roc': 0.6986904761904762}}, 'StackingClassifier': {'test': {'accuracy': 0.6, 'f1': 0.5454545454545454, 'auc_roc': 0.7425}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/german.csv
# BALANCING METHOD: smoteenn
#
# Status_loan
# 700
# 300
# Balanced X_train shape: (684, 61)
# Balanced y_train shape: (684,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.68, 'f1': 0.5789473684210527, 'auc_roc': 0.7746428571428572}}, 'XGBClassifier': {'test': {'accuracy': 0.69, 'f1': 0.5866666666666667, 'auc_roc': 0.7651190476190476}}, 'CatBoostClassifier': {'test': {'accuracy': 0.675, 'f1': 0.5806451612903226, 'auc_roc': 0.776904761904762}}, 'LightGBMClassifier': {'test': {'accuracy': 0.67, 'f1': 0.5657894736842105, 'auc_roc': 0.7546428571428571}}, 'StackingClassifier': {'test': {'accuracy': 0.67, 'f1': 0.5657894736842105, 'auc_roc': 0.7746428571428571}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/german.csv
# BALANCING METHOD: smotetomek
#
# Status_loan
# 700
# 300
# Balanced X_train shape: (1114, 61)
# Balanced y_train shape: (1114,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.765, 'f1': 0.5765765765765766, 'auc_roc': 0.789047619047619}}, 'XGBClassifier': {'test': {'accuracy': 0.77, 'f1': 0.5892857142857143, 'auc_roc': 0.7633333333333333}}, 'CatBoostClassifier': {'test': {'accuracy': 0.775, 'f1': 0.6341463414634146, 'auc_roc': 0.8089285714285714}}, 'LightGBMClassifier': {'test': {'accuracy': 0.755, 'f1': 0.5663716814159292, 'auc_roc': 0.7855952380952381}}, 'StackingClassifier': {'test': {'accuracy': 0.77, 'f1': 0.603448275862069, 'auc_roc': 0.7998809523809525}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/cleaned_hmeq.csv
# BALANCING METHOD: smote
#
# BAD
# 4771
# 1189
# Balanced X_train shape: (7634, 18)
# Balanced y_train shape: (7634,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.9312080536912751, 'f1': 0.8291666666666666, 'auc_roc': 0.9705596074907951}}, 'XGBClassifier': {'test': {'accuracy': 0.9362416107382551, 'f1': 0.8376068376068375, 'auc_roc': 0.9727331184045945}}, 'CatBoostClassifier': {'test': {'accuracy': 0.9328859060402684, 'f1': 0.8245614035087718, 'auc_roc': 0.9708216619981326}}, 'LightGBMClassifier': {'test': {'accuracy': 0.9261744966442953, 'f1': 0.8070175438596491, 'auc_roc': 0.9669679192431689}}, 'StackingClassifier': {'test': {'accuracy': 0.9387583892617449, 'f1': 0.8450106157112527, 'auc_roc': 0.9750761939996124}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/cleaned_hmeq.csv
# BALANCING METHOD: cc
#
# BAD
# 4771
# 1189
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Balanced X_train shape: (1902, 18)
# Balanced y_train shape: (1902,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.8926174496644296, 'f1': 0.773851590106007, 'auc_roc': 0.953275020700104}}, 'XGBClassifier': {'test': {'accuracy': 0.822986577181208, 'f1': 0.6758832565284179, 'auc_roc': 0.9449619470429681}}, 'CatBoostClassifier': {'test': {'accuracy': 0.8515100671140939, 'f1': 0.7131280388978931, 'auc_roc': 0.9415155999506722}}, 'LightGBMClassifier': {'test': {'accuracy': 0.8162751677852349, 'f1': 0.6686838124054463, 'auc_roc': 0.9404585733664534}}, 'StackingClassifier': {'test': {'accuracy': 0.8573825503355704, 'f1': 0.724025974025974, 'auc_roc': 0.949848492856262}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/cleaned_hmeq.csv
# BALANCING METHOD: smoteenn
#
# BAD
# 4771
# 1189
# Balanced X_train shape: (7377, 18)
# Balanced y_train shape: (7377,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.927013422818792, 'f1': 0.8160676532769555, 'auc_roc': 0.9665186829448761}}, 'XGBClassifier': {'test': {'accuracy': 0.9354026845637584, 'f1': 0.8300220750551878, 'auc_roc': 0.9672806229410004}}, 'CatBoostClassifier': {'test': {'accuracy': 0.9303691275167785, 'f1': 0.8183807439824946, 'auc_roc': 0.9671000475661964}}, 'LightGBMClassifier': {'test': {'accuracy': 0.9261744966442953, 'f1': 0.808695652173913, 'auc_roc': 0.9631494107076793}}, 'StackingClassifier': {'test': {'accuracy': 0.9345637583892618, 'f1': 0.832618025751073, 'auc_roc': 0.9711035357539243}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/cleaned_hmeq.csv
# BALANCING METHOD: smotetomek
#
# BAD
# 4771
# 1189
# Balanced X_train shape: (7632, 18)
# Balanced y_train shape: (7632,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.9345637583892618, 'f1': 0.8354430379746834, 'auc_roc': 0.968678981026373}}, 'XGBClassifier': {'test': {'accuracy': 0.9320469798657718, 'f1': 0.824295010845987, 'auc_roc': 0.9716893046526787}}, 'CatBoostClassifier': {'test': {'accuracy': 0.9295302013422819, 'f1': 0.8165938864628821, 'auc_roc': 0.9674788154255413}}, 'LightGBMClassifier': {'test': {'accuracy': 0.9320469798657718, 'f1': 0.8219780219780219, 'auc_roc': 0.9650124200623645}}, 'StackingClassifier': {'test': {'accuracy': 0.9354026845637584, 'f1': 0.8358208955223881, 'auc_roc': 0.9730458221024259}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/UCI_Credit_Card.csv
# BALANCING METHOD: smote
#
# default.payment.next.month
# 23364
# 6636
# Balanced X_train shape: (37382, 23)
# Balanced y_train shape: (37382,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.7933333333333333, 'f1': 0.5032051282051282, 'auc_roc': 0.7510537292670896}}, 'XGBClassifier': {'test': {'accuracy': 0.8018333333333333, 'f1': 0.481917211328976, 'auc_roc': 0.737431646888094}}, 'CatBoostClassifier': {'test': {'accuracy': 0.8131666666666667, 'f1': 0.4788470478847048, 'auc_roc': 0.7653617415443236}}, 'LightGBMClassifier': {'test': {'accuracy': 0.8085, 'f1': 0.48773963441818985, 'auc_roc': 0.7600545131639358}}, 'StackingClassifier': {'test': {'accuracy': 0.803, 'f1': 0.5033613445378151, 'auc_roc': 0.761949589030669}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/UCI_Credit_Card.csv
# BALANCING METHOD: cc
#
# default.payment.next.month
# 23364
# 6636
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Balanced X_train shape: (10618, 23)
# Balanced y_train shape: (10618,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.5463333333333333, 'f1': 0.42958927074601844, 'auc_roc': 0.68229850940265}}, 'XGBClassifier': {'test': {'accuracy': 0.45366666666666666, 'f1': 0.40007320644216693, 'auc_roc': 0.6306140503793618}}, 'CatBoostClassifier': {'test': {'accuracy': 0.45566666666666666, 'f1': 0.40596580574754454, 'auc_roc': 0.6552855950206021}}, 'LightGBMClassifier': {'test': {'accuracy': 0.47483333333333333, 'f1': 0.4111381050270977, 'auc_roc': 0.6587322577019358}}, 'StackingClassifier': {'test': {'accuracy': 0.4535, 'f1': 0.4037097654118931, 'auc_roc': 0.6433755556096681}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/UCI_Credit_Card.csv
# BALANCING METHOD: smoteenn
#
# default.payment.next.month
# 23364
# 6636
# Balanced X_train shape: (23261, 23)
# Balanced y_train shape: (23261,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.7625, 'f1': 0.5193929173693086, 'auc_roc': 0.7655142152057282}}, 'XGBClassifier': {'test': {'accuracy': 0.7701666666666667, 'f1': 0.5210142410559222, 'auc_roc': 0.7519377701045512}}, 'CatBoostClassifier': {'test': {'accuracy': 0.7833333333333333, 'f1': 0.5276162790697675, 'auc_roc': 0.7647597487595288}}, 'LightGBMClassifier': {'test': {'accuracy': 0.7733333333333333, 'f1': 0.5207892882311487, 'auc_roc': 0.7676589253695048}}, 'StackingClassifier': {'test': {'accuracy': 0.7661666666666667, 'f1': 0.5239226331862911, 'auc_roc': 0.764580586160036}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/UCI_Credit_Card.csv
# BALANCING METHOD: smotetomek
#
# default.payment.next.month
# 23364
# 6636
# Balanced X_train shape: (36094, 23)
# Balanced y_train shape: (36094,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
# {'RandomForestClassifier': {'test': {'accuracy': 0.7948333333333333, 'f1': 0.5120887831946095, 'auc_roc': 0.7556599497086873}}, 'XGBClassifier': {'test': {'accuracy': 0.802, 'f1': 0.4857142857142857, 'auc_roc': 0.7416536595049468}}, 'CatBoostClassifier': {'test': {'accuracy': 0.8133333333333334, 'f1': 0.48482060717571296, 'auc_roc': 0.7660819397165425}}, 'LightGBMClassifier': {'test': {'accuracy': 0.8111666666666667, 'f1': 0.5032880315651032, 'auc_roc': 0.7647998224822776}}, 'StackingClassifier': {'test': {'accuracy': 0.8041666666666667, 'f1': 0.511840465309514, 'auc_roc': 0.7617217251665076}}}
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# DATASET: /kaggle/input/dataset/FinalDatasetHomeCreditDefaultRisk.csv
# BALANCING METHOD: smote
#
# TARGET
# 226489
# 19806
# Balanced X_train shape: (362382, 1358)
# Balanced y_train shape: (362382,)
# Evaluating model: RandomForestClassifier
# Evaluating model: XGBClassifier
# Evaluating model: CatBoostClassifier
# Evaluating model: LightGBMClassifier
# Evaluating model: StackingClassifier
